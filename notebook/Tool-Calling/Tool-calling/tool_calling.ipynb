# %% [markdown]
# #### TOOL CALLING

# %% [markdown]
# ###### It is the process where the LLM decides during a conversation or task that it needs to use a specific tool(function) and generates a structured output with:  1. the name of the tool                                     2. the arguments to call it with

# %%
from langchain_openai import ChatOpenAI
from langchain_core.tools import tool
from langchain_core.messages import HumanMessage
import requests

# %%
# create tool
@tool
def multiply(a:int,b:int)-> int:
   """Given 2 numbers a and b"""
   return a*b

# %%
print(multiply.invoke({"a":2,"b":3}))

# %%
#tool binding
llm=ChatOpenAI()

# %%
llm_with_tools= llm.bind_tools([multiply])

# %%
llm_with_tools.invoke('Can you do multiply of 2 with 4').tool_Calls
llm_with_tools.invoke('Can you do multiply of 2 with 4').tool_Calls[0]
